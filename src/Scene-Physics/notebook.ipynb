# %%
import json

with open('objects/stimuli.json', 'r') as f:
    data = json.load(f)

# %%
trials = list(data.keys())

# %%
data[trials[0]].keys()
# Out:
# dict_keys(['conditions', 'ball_positions'])

# %%
data[trials[0]]['conditions']
# Out:
# {'ballType': 'ball_7',
#  'ballScale': 0.9753577541169486,
#  'rampDFriction': 0.06366294547725146,
#  'rampSFriction': 0.07575822676297515,
#  'forceVector': {'x': -0.12733866997846954,
#   'y': -0.0471961493218962,
#   'z': 0.4301990590606617},
#  'rampType': 'ramp_5m'}
