# %%
import pyvista as pv
import numpy as np

# %%
plotter = pv.Plotter(off_screen=True) 

# Add Shape
actor = plotter.add_mesh(pv.Sphere())

plotter.camera_position = [
    (1, 1, 1),
    (0, 0, 0),
    (0, 1, 0)
]

# Save image
plotter.screenshot("photo.png")

# 
zval = plotter.get_image_depth()
# Out:
# 2025-11-22 15:31:55.984 (   1.528s) [    14F89FF8D400]vtkXOpenGLRenderWindow.:1458  WARN| bad X server connection. DISPLAY=

# %%
data = np.array(zval)
